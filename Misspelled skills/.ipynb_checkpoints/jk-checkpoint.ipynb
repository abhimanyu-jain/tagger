# %%
import pandas as pd

# %%
# Using pyspellchecker to check spellings of all words
from spellchecker import SpellChecker

# %%
# Find if the words are nouns or not
# https://stackoverflow.com/questions/28033882/determining-whether-a-word-is-a-noun-or-not

from nltk.corpus import wordnet as wn
nouns = {x.name().split('.', 1)[0] for x in wn.all_synsets('n')}

# %%
def isNoun(str):
    if str in nouns:
        return True
    return False

print(isNoun('car'))
# Out:
# True

# %%
from nltk.corpus import wordnet as wn

# Just to make it a bit more readable
WN_NOUN = 'n'
WN_VERB = 'v'
WN_ADJECTIVE = 'a'
WN_ADJECTIVE_SATELLITE = 's'
WN_ADVERB = 'r'


def convert(word, from_pos, to_pos):    
    """ Transform words given from/to POS tags """

    synsets = wn.synsets(word, pos=from_pos)

    # Word not found
    if not synsets:
        return []

    # Get all lemmas of the word (consider 'a'and 's' equivalent)
    lemmas = []
    for s in synsets:
        for l in s.lemmas():
            if s.name().split('.')[1] == from_pos or from_pos in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE) and s.name().split('.')[1] in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE):
                lemmas += [l]

    # Get related forms
    derivationally_related_forms = [(l, l.derivationally_related_forms()) for l in lemmas]

    # filter only the desired pos (consider 'a' and 's' equivalent)
    related_noun_lemmas = []

    for drf in derivationally_related_forms:
        for l in drf[1]:
            if l.synset().name().split('.')[1] == to_pos or to_pos in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE) and l.synset().name().split('.')[1] in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE):
                related_noun_lemmas += [l]

    # Extract the words from the lemmas
    words = [l.name() for l in related_noun_lemmas]
    len_words = len(words)

    # Build the result in the form of a list containing tuples (word, probability)
    result = [(w, float(words.count(w)) / len_words) for w in set(words)]
    result.sort(key=lambda w:-w[1])

    # return all the possibilities sorted by probability
    return result


print(convert('direct', 'a', 'r'))
x = convert('direct', 'a', 'n')
print(convert('quick', 'a', 'r'))
print(convert('quickly', 'r', 'a'))
print(convert('hunger', 'n', 'v'))
print(convert('run', 'v', 'a'))
print(convert('tired', 'a', 'r'))
print(convert('tired', 'a', 'v'))
print(convert('tired', 'a', 'n'))
print(convert('tired', 'a', 's'))
print(convert('wonder', 'v', 'n'))
print(convert('wonder', 'n', 'a'))

print(x[0][0])
# Out:
# []
# []
# []
# [('hunger', 0.75), ('thirst', 0.25)]
# [('operant', 0.16666666666666666), ('persistent', 0.16666666666666666), ('operative', 0.16666666666666666), ('executive', 0.16666666666666666), ('prevalent', 0.16666666666666666), ('meltable', 0.16666666666666666)]
# []
# []
# [('commonplace', 0.25), ('tiredness', 0.25), ('triteness', 0.25), ('banality', 0.25)]
# []
# [('wonder', 0.3333333333333333), ('wonderer', 0.2222222222222222), ('marvel', 0.1111111111111111), ('wonderment', 0.1111111111111111), ('marveller', 0.1111111111111111), ('question', 0.1111111111111111)]
# [('curious', 0.4), ('wondrous', 0.2), ('marvellous', 0.2), ('marvelous', 0.2)]
# directness

# %%
# add all the words in chawla’s list (which are not in a normal dictionary) to a dictionary-aux. save that dictionary.

# %%
def print_dictionary(dic):
    for keys,values in dic.items():
        print(keys)
        print(values)

# %%
df1 = pd.read_csv("mysql-data-skills.csv")
df1
# Out:
#                  Skill
# 0           Accountant
# 1                Tally
# 2      Busy Accounting
# 3             Taxation
# 4                  GST
# ...                ...
# 21801               Zs
# 21802          Zscaler
# 21803      ZTE Telecom
# 21804            Zycus
# 21805            Zynga
#
# [21806 rows x 1 columns]

# %%
mysql_data_skills = df1['Skill'].tolist()

# %%
print(mysql_data_skills)
# Out:
# ['Accountant', 'Tally', 'Busy Accounting', 'Taxation', 'GST', 'TDS', 'Bank Reconciliation', 'Tally ERP.9', 'Junior Accountant', 'Account Assistant', 'Service Tax', 'Accounts Executive', 'Accountant manager', 'Paper & Document Keeper', 'Sale Tax', 'Account Executive', 'Excise', 'Billing', 'Busy Software', 'Excise & Customs', 'Accounting', 'BRS', 'Invoicing', 'General Ledger', 'Vat', 'CST', 'Income Tax Return', 'Bookkeeping', 'Income Tax', 'Accounting Vouchers', 'Advance Tax', 'Bank Reconcile', 'Accounts Officer', 'Account Manager', 'GST 3B', 'Ramco ERP 9', 'General Accounting', 'P&L Accounts', 'Costing', 'Cost Accountant', 'C FORM', 'DVAT', 'Junior Account', 'Indirect Tax', 'GST RETURNS', 'Daily Sales', 'Commercial Accountant', 'GST R2', 'GST R1', 'Invoice Processing', 'OnBase Software', 'Nuvas Software', 'Tally ERP', 'Zoho Office Suite', 'Profit Books', 'Cashier', 'Retail Cashier', 'Billing Operator', 'Billing Cashier Assistant', 'Professional Loan Sales', 'Billing Counter Executive', 'Billing Counter', 'Head Cashier', 'Billing Accountant', 'Cash Counter Executive', 'Cash Collection', 'Cash Management', 'ATM Operations', 'Gournal Book', 'Chartered Accountant', 'Audit', 'Finance', 'Finance Analyst', 'Finance Executive', 'CA', 'Internal Auditor', 'Finance Advisor', 'Loan Advisor', 'Insurance Advisor', 'C A Assistant', 'Corporate Finance', 'Auditor Assistant', 'Statutory Audit', 'Auditor', 'SAP Accounting', 'Chief Financial Officer', 'SAP Consultant', 'Finance Control', 'ICWA', 'CPA', 'IPCC', 'CFA', 'CMA', 'CPT', 'Standard Costing', 'Cash Flow', 'Tax Audit', 'Revenue Audit', 'Company Audit', 'Transfer Pricing', 'Concurrent Audit', 'International Taxation', 'Business Restructuring', 'Tax Planning', 'Tax Reporting', 'Due Diligence', 'SOX', 'SOX Compliance', 'ROC Compliance', 'FDI', 'Company Secretary', 'Secretarial Compliance', 'Legal', 'CORPORATE CONSULTANCY', 'Associate Company Secretary', 'Corporate Governance', 'Personal Loan Sales', 'Legal and Finance', 'Automobile Spare Parts Sales', 'Legal Compliance', 'Corporate Law', 'Legal Advisor', 'Companies Act', 'RBI', 'Securities Law', 'IPO', 'FEMA', 'Wage Administration', 'Legal Cases', 'CSS', 'Sales', 'Sales Executive', 'Field Executive', 'Spare Parts Sales', 'Area Sales Manager', 'Sales Manager', 'Salesman', 'Sales Officer', 'Sales Coordinator', 'Salesgirl', 'Auto Parts Sales', 'Regional Sales Manager', 'Sales Development Manager', 'Sales Tax Return Assessment', 'First Sales Manger', 'Field Sales', 'Sales Coordination', 'Sales Representative', 'Primary And Secondary Sales', 'Sales & Purchase Executive', 'Channel Sales', 'CSD CPC Sales', 'Sales & Service Head', 'Loan Sales', 'Sales Accountant', 'Sr Sales Officer', 'Sales BD', 'Sales Promoter', 'Sales Operater', 'Senior Sales Manager', 'Sales Boy', 'Sales Office Coordinator', 'Sales FMCG', 'Sr Sales Manager', 'Field Sales Officer', 'Textile Sales Executive', 'Direct Sales', 'Customer Sales Executive', 'Area Sales Officer', 'Sales Finance', 'Export Sales Manager', 'Sales Incharge', 'B2B Sales', 'Corporate Sales Manager', 'Associate Sales Manager', 'Corporate Sales Executive', 'Sales Operations Executive', 'Business Sales Associate', 'Professional Sales Officer', 'Presales', 'Team Sales Manager', 'National Sales Manager', 'Domestic Sales Executive', 'Export Sales', 'Operation Sales', 'Mechanical Sales', 'Unit Sales Manager', 'Sales Associates', 'Distribution Channel Sales', 'Zonal Sales Manager', 'Inside Sales Engineer', 'Insurance Sales', 'District Sales Manager', 'Regional Sales  Manager', 'General Sales Manager', 'Loan Sales Executive', 'Finance Sales Executive', 'Supplier Coordination', 'Sales Support', 'AGM Sales', 'Industrial Sales', 'Automobile', 'Auto Mechanic', 'Denting Painting', 'Automobile Mechanic', 'Automobile Maintenance', 'Automobile Work', 'Automobile Supervisor', 'Automobile Technician', 'Auto Parts Packaging', 'Automobile Parts Maker', 'AC Car Technician', 'Mechanic', 'Auto Rickshaw Mechanic', 'Car Mechanic', 'Surve ...

# %%
df2 = pd.read_csv("skills-active-12052021.csv")
df2
# Out:
#                                     name                               alias  \
# 0                             Accountant                     accountant-jobs
# 1                                  Tally                          tally-jobs
# 2                        Busy Accounting                busy-accounting-jobs
# 3                               Taxation                       taxation-jobs
# 4                                    GST                            gst-jobs
# ...                                  ...                                 ...
# 22001           Poclain Machine Operator       poclain-machine-operator-jobs
# 22002           Foiling Machine Operator       foiling-machine-operator-jobs
# 22003                            Forging                        forging-jobs
# 22004      Floor Boring Machine Operator  floor-boring-machine-operator-jobs
# 22005  Biesse Rover CNC Machine Operator  machine-operator-biesse-rover-jobs
#
#        status
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 22001       1
# 22002       1
# 22003       1
# 22004       1
# 22005       1
#
# [22006 rows x 3 columns]

# %%
skills_active = df2['name'].tolist()
print(skills_active)
# Out:
# ['Accountant', 'Tally', 'Busy Accounting', 'Taxation', 'GST', 'TDS', 'Bank Reconciliation', 'Tally ERP.9', 'Junior Accountant', 'Account Assistant', 'Service Tax', 'Accounts Executive', 'Accountant manager', 'Paper & Document Keeper', 'Sale Tax', 'Account Executive', 'Excise', 'Busy Software', 'Excise & Customs', 'Accounting', 'BRS', 'Invoicing', 'General Ledger', 'Vat', 'CST', 'Income Tax Return', 'Bookkeeping', 'Income Tax', 'Accounting Vouchers', 'Advance Tax', 'Bank Reconcile', 'Accounts Officer', 'Account Manager', 'GST 3B', 'Ramco ERP 9', 'General Accounting', 'P&L Accounts', 'Costing', 'Estimating And Costing', 'Execution', 'Cost Accountant', 'C FORM', 'DVAT', 'Junior Account', 'Indirect Tax', 'GST RETURNS', 'Daily Sales', 'Commercial Accountant', 'GST R2', 'GST R1', 'Invoice Processing', 'OnBase Software', 'Nuvas Software', 'Tally ERP', 'Zoho Office Suite', 'Profit Books', 'Gournal Book', 'Sales Tax Return Assessment', 'File Clerk', 'Purchase & Retrun Entries', 'GST Trainer', 'Lead Financial Accountant', 'Senior Accountant', 'Teller', 'Reconciliation Accountant', 'Sr Account Manager', 'Taxation Executive', 'Sr Accounts Executive', 'Assistant Accountant', 'Senior Account Manager', 'Sr Accountant', 'Accountant Executive', 'Busy Accountant', 'Accounts Manager', 'Taxation Manager', 'Commercial Manager', 'Avp Accounts', 'Cashier', 'Billing', 'Retail Cashier', 'Billing Operator', 'Billing Cashier Assistant', 'Billing Counter Executive', 'Billing Counter', 'Head Cashier', 'Billing Accountant', 'Cash Counter Executive', 'Cash Collection', 'Cash Management', 'Billing Executive', 'Senior Cashier', 'Manual Billing', 'Chartered Accountant', 'Audit', 'Finance', 'Finance Analyst', 'Finance Executive', 'CA', 'Internal Auditor', 'Finance Advisor', 'Loan Advisor', 'C A Assistant', 'Corporate Finance', 'Auditor Assistant', 'Statutory Audit', 'Auditor', 'SAP Accounting', 'Chief Financial Officer', 'SAP Consultant', 'Finance Control', 'ICWA', 'CPA', 'IPCC', 'CFA', 'CMA', 'CPT', 'Standard Costing', 'Cash Flow', 'Tax Audit', 'Revenue Audit', 'Company Audit', 'Transfer Pricing', 'Concurrent Audit', 'International Taxation', 'Business Restructuring', 'Tax Planning', 'Tax Reporting', 'Due Diligence', 'SOX', 'SOX Compliance', 'ROC Compliance', 'FDI', 'Commercial Officer', 'Sr Finance Analyst', 'Sr Chartered Accountant', 'Jr Chartered Accountant', 'Finance Head', 'Company Secretary', 'Secretarial Compliance', 'CORPORATE CONSULTANCY', 'Associate Company Secretary', 'Corporate Governance', 'Corporate Law', 'Companies Act', 'RBI', 'Securities Law', 'IPO', 'FEMA', 'Wage Administration', 'Legal Cases', 'CSS', 'Legal', 'Legal and Finance', 'Legal Compliance', 'Legal Advisor', 'Legal And Compliance', 'Criminal Lawyer', 'Lawyer', 'Legal Analyst', 'Custom Lawyer', 'Corporate Legal Advisor', 'Assistant Legal Advisor', 'Junior Legal Officer', 'Legal Department', 'Legal Assistant', 'Advisor', 'Legal Executive', 'Sales', 'Insurance Advisor', 'Lic Advisor', 'Lic Agent', 'Automobile Spare Parts Sales', 'Sales Executive', 'Field Executive', 'Spare Parts Sales', 'Area Sales Manager', 'Sales Manager', 'Salesman', 'Sales Officer', 'Sales Coordinator', 'Salesgirl', 'Auto Parts Sales', 'Auto Parts', 'Regional Sales Manager', 'Sales Development Manager', 'First Sales Manger', 'Field Sales', 'Sales Coordination', 'Sales Representative', 'Primary And Secondary Sales', 'Sales & Purchase Executive', 'Channel Sales', 'CSD CPC Sales', 'Sales & Service Head', 'Sales Accountant', 'Sr Sales Officer', 'Sales BD', 'Sales Promoter', 'Sales Operater', 'Senior Sales Manager', 'Sales Boy', 'Sales Office Coordinator', 'Sales FMCG', 'Sr Sales Manager', 'Field Sales Officer', 'Textile Sales Executive', 'Direct Sales', 'Customer Sales Executive', 'Area Sales Officer', 'Sales Finance', 'Export Sales Manager', 'Sales Incharge', 'B2B Sales', 'Corporate Sales Manager', 'Associate Sales Manager', 'Corporate Sales Executive', 'Sales Operations Executive', 'Business Sales Associate', 'Profess ...

# %%
# take the whole list of skills
# eliminate useless whitespace
# delete the ones which are there in chawla’s list
# among the remaining skills, create dictionary of skill name -> list of words
# check each word in dictionary and aux
# if all words are present in these, mark it as validated
# otherwise mark as invalid and create a replacement list with correct spellings.
# if all words could be corrected, convert list to string and save
# otherwise save “No replacement found"

# %%
# function to check if a string exists in another list of strings

def string_search(string, lst):
    if string in lst:
        return True
    return False

print(string_search('Sales Accountant', skills_active))
print(string_search('Sales Aant', skills_active))
# Out:
# True
# False

# %%
# Function to eliminate useless whitespace

def remove_whitespace(string):
    return " ".join(string.split())

print(remove_whitespace("kjhkjh     kjhk                   \t\t\t  jhgjhg"))
# Out:
# kjhkjh kjhk jhgjhg

# %%
# Function to convert list of strings into dictionary of unique constituent words

def getConstituentWords(lst):
    
    words = set([])
    
    for string in lst:
        word_lst = string.split()
        for word in word_lst:
            words.add(word)
            
    return words

print(getConstituentWords(['jkhkj kjhkjh', 'jhgjhg kjhhkjh']))
# Out:
# {'kjhkjh', 'jkhkj', 'jhgjhg', 'kjhhkjh'}

# %%
# Obtain mysql_data_words

mysql_data_words = getConstituentWords(mysql_data_skills)
print(mysql_data_words)
# Out:
# {'Endocrinology', 'CNG', 'Companies', 'Anand', 'Coremetrics', 'Trasers', 'Ubs', 'Globe', 'Ixigo', 'Telephone', 'Cooper', 'Hsse', 'DJ', 'Chairman', 'Relational', 'Tigers', 'Zynga', '(female)', 'Two', 'Keeper', 'Talpro', 'loan.graduates.', 'ubuntu', 'Wall', 'Infrrd', 'Chemisrty', 'Proper', 'UV-3600', 'MySQL.', 'Accoutant', 'Asia', 'Interest', 'architechture', 'Ibm', 'Teamcenter', 'Powder', 'merchandiser', 'OS', '(rn)', '12', 'CRC', 'Xcelsius', 'azure', 'Upload', 'Think', 'Ibaset', 'fleet', 'SLA', 'Payrolls', 'Vidyartha', 'Jumpwhere', 'Winery', 'Yoga', 'Uolo', 'Dt', 'Precise', 'ITSM', 'Whole', 'State', 'us', 'Knitwear', 'Canadian', 'Microsof', '(Statistics)', 'Builder', 'Tachnician', 'Ceh', 'Hour', 'Suite', 'Backend', 'Sushi', 'Techno', 'Spring.Net', 'Centre', 'card', 'Mig)', 'Alois', 'Gastrologist', 'Reverse', 'Sleeper', 'RAC', 'Ziphertech', 'Cypress', 'Technology', 'Marsh', 'Sundus', 'Routing', 'Dotsquares', 'Netbackup', 'Justdial', 'Jacobs', 'Sampling', 'Academies', 'Activ', 'PDMS', 'ENGLISH', 'Robotics', 'Shifts', 'UK', 'Fareye', 'consumer', 'programmer', 'Pcb', 'Physiologist', 'PowerPlay', 'Bulls', 'Infolabs', 'Jifflenow', 'Hippo', 'Convosight', 'Ultrasound', 'Placment', 'Com', 'Singh', 'Advance', 'Seven', 'Tom', 'Tact.ai', 'Wildlife', 'Conduent', 'BDE', 'Delivery', 'Bob', 'MS-DOS', 'Storehippo', 'J.p.', 'ORMS', 'Administration', 'Overseaas', 'internet', 'Evoke', 'Lawtendo', 'RBI', 'Partitioning', 'safety', 'Initiatives', 'Machinery', 'MSD', 'against', 'Enphase', 'Saksham', 'Patty', 'Start', 'Techblocks', 'RDS', 'Finishing', 'Bureau', 'Armor', 'Zigzag', 'NIM', 'budigere', 'Fundreamz', 'Services.', 'Pythian', 'Agribusiness', 'Captive', 'Derivatives', 'Warrant', 'optimisation', 'To', '2012', 'over', 'Mitratech', 'EDM', 'Dy', 'Command', 'personal', 'Cinematographer', 'CATI', 'Itiviti', 'Seam', 'Headmistress', 'Winding', 'Unacademy', 'Auto', 'Vlookup', 'Electronics', 'broker', 'Halliburton', 'GMAW', 'Delta', 'Practitioner', 'concepts', 'Companys', 'Sqlite', 'Bi', 'Tandem', 'Schema', 'Soa', 'Sorter', 'Netzens', 'OZU', 'reconciliation', 'Brick&bolt', 'Ece', 'Investigator', 'Aerodynamic', 'UPLC', 'Lido', 'Personalised', 'Airlines', 'Surveyor', 'Sysvine', 'userinterface', 'U:', 'PLC', 'Technique', 'Winform', 'Quintype', 'Sanitaryware', '360', 'control', 'Ui/Ux', 'Sous', 'Superintendent', 'project', 'Ans', 'Atria', 'Glender', 'Surgical', 'Elements', 'Mask', 'Inhouse', 'Dc', '-', 'Calling', 'Expeditor', 'Game', 'mbanking', 'MTech', 'WebLogic', 'Xcess', 'Pressure', 'Elecitation', 'AM-', 'Quess', 'Js', 'Vibrantzz', 'Service', 'electronics', 'Astrazeneca', 'Eazydiner', 'Nephrology', 'Aso', 'Walder', 'phosphates', 'ROC', 'Bucket', 'Chillakur', 'Ultrasonographer', 'Dezven', 'Trademark', 'Dassault', 'Lte', 'MISReports', 'OD', 'Tiswadi', 'commercial', 'Methodologies', 'Depository', 'Citizens', 'nanyang', 'Instructor', 'Hbase', 'Nous', 'Cardboard', 'Engineer,', 'Pepsico', 'Counter', 'Packers', 'Snowflake', 'mvc5', 'Tuner', 'Goal', 'MOSS', 'olx', 'presidency', 'Calypso', 'Yfc', 'Scio', 'Album', 'Mayo', 'Cgi', 'direct', 'production', 'Admin', 'Java/J2EE', 'Easy', 'Tekskills', 'Webware.io', 'Vhunt4u', 'Wealth42', 'Distributor', 'Chennai', 'Graphics', 'Retention', 'multi-threading', 'Weighing', 'Oil', 'Star', 'presentation', 'room', 'framework', 'Customer', 'environment', 'Blenheim', 'Proofer', 'Purpose', 'Mfc', 'SOAP', 'Jnu', 'advertising', 'Defense', 'ddr', 'Behavioral', 'Hirextra', 'CR', 'Avp', 'UV', 'Mds', 'Pusaur', 'Dipatch', 'Dye', 'Adjunct', 'Single', 'Preventive', 'petro', 'Zf', 'Brokers', 'Microbiology', 'Site', 'Cameraman', 'operator', 'Salary', 'Cold', 'Intellify', 'Ink', 'Antal', 'steno', 'Frame', 'Plast', 'TPF', 'Station', 'Cit', 'Rackspace', 'Tatvasoft', 'Bioinformatician', 'Engineerbabu', 'view', 'Procter', 'Theater', 'Khed', 'Centering', 'Inspection', 'Valuelabs', 'Picker', 'Wordpress', 'M2M', 'Booking', 'Supervise', 'Arminus', 'Businees', 'Lizlyn', 'Chuchu', 'Hn', 'Animal', 'Hotstar', 'Underwriting', 'UG', 'Newsletters', 'T&D', ' ...

# %%
# Obtain skills_active_words

skills_active_words = getConstituentWords(skills_active)
print(skills_active_words)
# Out:
# {'Endocrinology', 'CNG', 'Companies', 'Anand', 'Coremetrics', 'Trasers', 'Ubs', 'Globe', 'Ixigo', 'Telephone', 'Cooper', 'Hsse', 'DJ', 'Chairman', 'Relational', 'Tigers', 'Zynga', '(female)', 'Two', 'Keeper', 'Talpro', 'loan.graduates.', 'ubuntu', 'Wall', 'Infrrd', 'problem', 'Chemisrty', 'Proper', 'UV-3600', 'MySQL.', 'Accoutant', 'Asia', 'Interest', 'architechture', 'Ibm', 'Teamcenter', 'Powder', 'OS', '(rn)', '12', 'CRC', 'Xcelsius', 'azure', 'Upload', 'Think', 'Assistant,', 'Ibaset', 'fleet', 'SLA', 'Payrolls', 'Vidyartha', 'Jumpwhere', 'Winery', 'Yoga', 'telecommunication', 'Uolo', 'Dt', 'Precise', 'ITSM', 'Whole', 'State', 'us', 'Knitwear', 'Canadian', 'Microsof', '(Statistics)', 'Builder', 'Tachnician', 'Hour', 'Suite', 'operating', 'Backend', 'Sushi', 'Techno', 'WARRANT', 'WORKING', 'Spring.Net', 'Eletrical', 'Centre', 'card', 'Mig)', 'Alois', 'Gastrologist', 'leader,', 'Reverse', 'Sleeper', 'RAC', 'Ziphertech', 'Mechanich', 'Cypress', 'Technology', 'Marsh', 'Sundus', 'Routing', 'Dotsquares', 'Netbackup', 'Justdial', 'Subathraramesh', 'Jacobs', 'Sampling', 'Academies', 'PDMS', 'ENGLISH', 'Robotics', 'Shifts', 'UK', 'Fareye', 'consumer', 'programmer', 'Pcb', 'Physiologist', 'PowerPlay', 'Bulls', 'Infolabs', 'Jifflenow', 'Hippo', 'Convosight', 'Ultrasound', 'Placment', 'maintanance', 'Com', 'Singh', 'Rushabh', 'Advance', 'Seven', 'extension', 'Tom', 'Tact.ai', 'Shripriya', 'Wildlife', 'Conduent', 'for', 'Delivery', 'BDE', 'Bob', 'MS-DOS', 'Storehippo', 'J.p.', 'ORMS', 'Administration', 'Overseaas', 'internet', 'Evoke', 'Lawtendo', 'RBI', 'BRANCH', 'EXPERIENCE', 'Partitioning', 'safety', 'Initiatives', 'Machinery', 'MSD', 'against', 'Enphase', 'Patty', 'Start', 'Techblocks', 'RDS', 'Finishing', 'Bureau', 'Armor', 'Zigzag', 'NIM', 'budigere', 'Fundreamz', 'Services.', 'Pythian', 'Agribusiness', 'Captive', 'Derivatives', 'Warrant', 'optimisation', 'To', '2012', 'over', 'Mitratech', 'EDM', 'Dy', 'Command', 'personal', 'diesel', 'shot', 'Cinematographer', 'CATI', 'Itiviti', 'Seam', 'Headmistress', 'Winding', 'Unacademy', 'Auto', 'Vlookup', 'Electronics', 'broker', 'Halliburton', 'GMAW', 'Delta', 'Practitioner', 'concepts', 'Companys', 'Sqlite', 'Bi', 'Tandem', 'Schema', 'Soa', 'Sorter', 'Netzens', 'OZU', 'reconciliation', 'Brick&bolt', 'WITH', 'Ece', 'Investigator', 'Aerodynamic', 'UPLC', 'Poclain', 'Lido', 'Personalised', 'Airlines', 'Surveyor', 'Sysvine', 'userinterface', 'U:', 'PLC', 'Technique', 'Winform', 'Quintype', 'Sanitaryware', '360', 'control', 'Ui/Ux', 'Sous', 'Superintendent', 'project', 'Ans', 'Atria', 'Glender', 'Surgical', 'Elements', 'Mask', 'Inhouse', 'Dc', '-', 'Calling', 'Expeditor', 'Game', 'mbanking', 'STORE', 'MTech', 'Xcess', 'Jop', 'Pressure', 'Elecitation', 'AM-', 'Quess', 'Js', 'Vibrantzz', 'Service', 'electronics', 'Astrazeneca', 'Eazydiner', 'Nephrology', 'Aso', 'phosphates', 'ROC', '+)', 'Bucket', 'Chillakur', 'Ultrasonographer', 'Dezven', 'Trademark', 'Machin', 'Dassault', 'Lte', 'MISReports', 'OD', 'Tiswadi', 'commercial', 'Methodologies', 'Depository', 'Citizens', 'nanyang', 'Instructor', 'Hbase', 'Crs).', 'Nous', 'Cardboard', 'Engineer,', 'Pepsico', 'PPt', 'Counter', 'Packers', 'Snowflake', 'mvc5', 'Tuner', 'Goal', 'MOSS', 'olx', 'presidency', 'Calypso', 'Yfc', 'Scio', 'Album', 'Mayo', 'Cgi', 'direct', '(INDIA)', 'production', 'Admin', 'Java/J2EE', 'Easy', 'Tekskills', 'Webware.io', 'Vhunt4u', 'Wealth42', 'Distributor', 'Chennai', 'Graphics', 'Retention', 'multi-threading', 'Oil', 'Weighing', 'Star', 'presentation', 'room', 'Elavarasan86', 'framework', 'Customer', 'environment', 'Blenheim', 'Proofer', 'Purpose', 'Mfc', 'SOAP', 'Jnu', 'advertising', 'Defense', 'ddr', 'Behavioral', 'Hirextra', 'CR', 'Avp', 'UV', 'Mds', 'startup', 'Pusaur', 'Dipatch', 'Dye', 'Adjunct', 'Single', 'Preventive', 'petro', 'Zf', 'Brokers', 'Microbiology', 'Site', 'Cameraman', 'operator', 'Salary', 'Cold', 'Intellify', 'Ink', 'Antal', 'Frame', 'TPF', 'Station', 'Cit', 'Rackspace', 'Tatvasoft', 'Bioinformatician', 'Eng ...

# %%
# Word_analysis class
#    Original_word
#    found_in_mysql_data_words
#    found_in_skills_active_words
#    spellchecked_replacement
#    noun_or_not
#    nounified_word

class WordAnalysis:
    
    def __init__(self, originalWord):
        self.originalWord = originalWord
        self.found_in_mysql_data_words = string_search(self.originalWord, mysql_data_words)
        self.found_in_skills_active_words = string_search(self.originalWord, skills_active_words)
        self.spellcheck()
        
        
    def spellcheck(self):
        if(self.found_in_mysql_data_words == False & self.found_in_skills_active_words):
            spell = SpellChecker()
            self.spellCheckedWord = spell.correction(self.originalWord)
        else:
            self.spellCheckedWord = self.originalWord
        
    def getSpellcheckedWord(self):
        return self.spellCheckedWord
    
    def nounCheck(self):
        self.is_noun = isNoun(self.self.spellCheckedWord)
        
        
    def printValues(self):
        print("Original word : ", self.originalWord)
        print("Does word exist in mysql_data_words : ", self.found_in_mysql_data_words)
        print("Does word exist in skills_active_words : ", self.found_in_skills_active_words)
        

w1 = WordAnalysis("Paisadukan")
w1.printValues()

w2 = WordAnalysis("kjhkjh")
w2.printValues()

w3 = WordAnalysis("Account")
w3.printValues()
# Out:
# Original word :  Paisadukan
# Does word exist in mysql_data_words :  True
# Does word exist in skills_active_words :  True
# Original word :  kjhkjh
# Does word exist in mysql_data_words :  False
# Does word exist in skills_active_words :  False
# Original word :  Account
# Does word exist in mysql_data_words :  True
# Does word exist in skills_active_words :  True

# %%
#Output class:

# String Original_Skill_Name
# Boolean skill_found_in_mysql_data_skills
# Boolean skill_found_in_skills_active
# List of strings Original_skill_words
# Function to convert skill into list of words
# List: 
#      Word_analysis object for each word
# String replacement_string

class SkillAnalysis:
    
    def __init__(self, originalSkill):
        self.originalSkill = remove_whitespace(originalSkill)
        self.skill_found_in_mysql_data_skills = string_search(self.originalSkill, mysql_data_skills)
        self.skill_found_in_skills_active = string_search(self.originalSkill, skills_active)
        self.word_lst = self.originalSkill.split()
        self.word_analysis_lst = []
        
        for word in self.word_lst:
            w = WordAnalysis(word)
            #w.printValues()
            self.word_analysis_lst.append(w)
            
        self.correctedSkill = ''
        
        for w in self.word_analysis_lst:
            self.correctedSkill = self.correctedSkill + w.getSpellcheckedWord() + ' '
            
        self.correctedSkill = remove_whitespace(self.correctedSkill)
        #print(self.correctedSkill)
        
    def getCorrectedSkill(self):
        return self.correctedSkill
            

s = SkillAnalysis('Tool Develobment Engineer')

# %%
import ssl 
from pymongo import MongoClient
client = MongoClient('localhost:27017')
db = client.the_incircle_dev_new_may_27_2021
skills = db.skills
print(db.skills.count())
# Out:
# 33907
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere

# %%
originalSkills = []
replacementSkills = []

skill_cursor = skills.find()
skill_cursor.rewind()

for skill in skill_cursor:
    skillName = skill['name']
    originalSkills.append(skillName)
    ska = SkillAnalysis(skillName)
    replacementSkills.append(ska.getCorrectedSkill())

# %%
print(len(originalSkills))
print(len(replacementSkills))
# Out:
# 33907
# 33907

# %%
import pandas as pd
skill_replacement_list = pd.DataFrame(
    {'Original Skill': originalSkills,
     'Replacement Skill': replacementSkills
    })
skill_replacement_list.to_excel("skill_replacement_list2.xlsx")

# %%
skill_ids = []

for skill_name in originalSkills:
    skill_id = skills.find_one({'name' : skill_name})
    #print(skill_name, skill_id['_id'])
    skill_ids.append(skill_id['_id'])

# %%
skill_replacement_list['skill_id'] = skill_ids
skill_replacement_list
# Out:
#                  Original Skill         Replacement Skill  \
# 0                    Accountant                Accountant
# 1                         Tally                     Tally
# 2               Busy Accounting           Busy Accounting
# 3                      Taxation                  Taxation
# 4                           GST                       GST
# ...                         ...                       ...
# 33902                    Turner                    Turner
# 33903  High Voltage Electrician  High Voltage Electrician
# 33904     Bolt Machine Operator     Bolt Machine Operator
# 33905     Bolt Machine Operator     Bolt Machine Operator
# 33906       Construction Welder       Construction Welder
#
#                        skill_id
# 0      5f7ef8d57d5d3a013307ddb4
# 1      5f7ef8d57d5d3a013307ddb7
# 2      5f7ef8d57d5d3a013307ddba
# 3      5f7ef8d57d5d3a013307ddbd
# 4      5f7ef8d57d5d3a013307ddc0
# ...                         ...
# 33902  5f7efc687d5d3a0133097539
# 33903  608fa92c3b28ce3a38c31576
# 33904  604a5c2435b38c6e3db41e30
# 33905  604a5c2435b38c6e3db41e30
# 33906  6050e4f333fd7b27ed86b557
#
# [33907 rows x 3 columns]

# %%
import numpy as np
skill_replacement_list['Comparison'] = np.where(skill_replacement_list['Original Skill'].eq(skill_replacement_list['Replacement Skill']), 'True', 'False')
skill_replacement_list
# Out:
#                  Original Skill         Replacement Skill  \
# 0                    Accountant                Accountant
# 1                         Tally                     Tally
# 2               Busy Accounting           Busy Accounting
# 3                      Taxation                  Taxation
# 4                           GST                       GST
# ...                         ...                       ...
# 33902                    Turner                    Turner
# 33903  High Voltage Electrician  High Voltage Electrician
# 33904     Bolt Machine Operator     Bolt Machine Operator
# 33905     Bolt Machine Operator     Bolt Machine Operator
# 33906       Construction Welder       Construction Welder
#
#                        skill_id Comparison
# 0      5f7ef8d57d5d3a013307ddb4       True
# 1      5f7ef8d57d5d3a013307ddb7       True
# 2      5f7ef8d57d5d3a013307ddba       True
# 3      5f7ef8d57d5d3a013307ddbd       True
# 4      5f7ef8d57d5d3a013307ddc0       True
# ...                         ...        ...
# 33902  5f7efc687d5d3a0133097539       True
# 33903  608fa92c3b28ce3a38c31576       True
# 33904  604a5c2435b38c6e3db41e30       True
# 33905  604a5c2435b38c6e3db41e30       True
# 33906  6050e4f333fd7b27ed86b557       True
#
# [33907 rows x 4 columns]

# %%
skill_replacement_list.to_excel("skill_replacement_list2.xlsx")

# %%
skill_replacement_list['Spacing fixed'] = skill_replacement_list['Original Skill'].apply(remove_whitespace)
skill_replacement_list
# Out:
#                  Original Skill         Replacement Skill  \
# 0                    Accountant                Accountant
# 1                         Tally                     Tally
# 2               Busy Accounting           Busy Accounting
# 3                      Taxation                  Taxation
# 4                           GST                       GST
# ...                         ...                       ...
# 33902                    Turner                    Turner
# 33903  High Voltage Electrician  High Voltage Electrician
# 33904     Bolt Machine Operator     Bolt Machine Operator
# 33905     Bolt Machine Operator     Bolt Machine Operator
# 33906       Construction Welder       Construction Welder
#
#                        skill_id Comparison             Spacing fixed
# 0      5f7ef8d57d5d3a013307ddb4       True                Accountant
# 1      5f7ef8d57d5d3a013307ddb7       True                     Tally
# 2      5f7ef8d57d5d3a013307ddba       True           Busy Accounting
# 3      5f7ef8d57d5d3a013307ddbd       True                  Taxation
# 4      5f7ef8d57d5d3a013307ddc0       True                       GST
# ...                         ...        ...                       ...
# 33902  5f7efc687d5d3a0133097539       True                    Turner
# 33903  608fa92c3b28ce3a38c31576       True  High Voltage Electrician
# 33904  604a5c2435b38c6e3db41e30       True     Bolt Machine Operator
# 33905  604a5c2435b38c6e3db41e30       True     Bolt Machine Operator
# 33906  6050e4f333fd7b27ed86b557       True       Construction Welder
#
# [33907 rows x 5 columns]

# %%
skill_replacement_list['Spacing Comparison'] = np.where(skill_replacement_list['Replacement Skill'].eq(skill_replacement_list['Spacing fixed']), 'True', 'False')
skill_replacement_list
# Out:
#                  Original Skill         Replacement Skill  \
# 0                    Accountant                Accountant
# 1                         Tally                     Tally
# 2               Busy Accounting           Busy Accounting
# 3                      Taxation                  Taxation
# 4                           GST                       GST
# ...                         ...                       ...
# 33902                    Turner                    Turner
# 33903  High Voltage Electrician  High Voltage Electrician
# 33904     Bolt Machine Operator     Bolt Machine Operator
# 33905     Bolt Machine Operator     Bolt Machine Operator
# 33906       Construction Welder       Construction Welder
#
#                        skill_id Comparison             Spacing fixed  \
# 0      5f7ef8d57d5d3a013307ddb4       True                Accountant
# 1      5f7ef8d57d5d3a013307ddb7       True                     Tally
# 2      5f7ef8d57d5d3a013307ddba       True           Busy Accounting
# 3      5f7ef8d57d5d3a013307ddbd       True                  Taxation
# 4      5f7ef8d57d5d3a013307ddc0       True                       GST
# ...                         ...        ...                       ...
# 33902  5f7efc687d5d3a0133097539       True                    Turner
# 33903  608fa92c3b28ce3a38c31576       True  High Voltage Electrician
# 33904  604a5c2435b38c6e3db41e30       True     Bolt Machine Operator
# 33905  604a5c2435b38c6e3db41e30       True     Bolt Machine Operator
# 33906  6050e4f333fd7b27ed86b557       True       Construction Welder
#
#       Spacing Comparison
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 33902               True
# 33903               True
# 33904               True
# 33905               True
# 33906               True
#
# [33907 rows x 6 columns]

# %%
skill_replacement_list.to_excel("skill_replacement_list3.xlsx")
