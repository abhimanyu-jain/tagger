# %%
import xlrd
from bson.objectid import ObjectId

loc = ("skills-single-parent-active.xls")
wb = xlrd.open_workbook(loc)
sheet = wb.sheet_by_index(0)
print(sheet.cell_value(15287, 1))
# Out:
# "5ff950f868130d34c7869870"

# %%
# Iterate over sheet and create lists of ids and skill names

lst_ids = []
lst_names = []

max_rows = 15288


for row in range(1, max_rows):
    _id = str(sheet.cell_value(row, 1))
    _id = _id[1:len(_id)-1]
    name = sheet.cell_value(row, 2)

    lst_ids.append(_id)
    lst_names.append(name)
    

print('Number of ids : ',len(lst_ids))
print('Number of names : ', len(lst_names))
# Out:
# Number of ids :  15287
# Number of names :  15287

# %%
name_to_list_of_words_mapping = {}

for name in lst_names:
    name_to_list_of_words_mapping[name] = name.split()
    
print(name_to_list_of_words_mapping['Nail Artist'])
# Out:
# ['Nail', 'Artist']

# %%
loc2 = ("qualified_parents.xls")
wb2 = xlrd.open_workbook(loc2)
sheet2 = wb2.sheet_by_index(0)
print(sheet2.cell_value(110, 1))
# Out:
# Web Designer

# %%
qualified_parents = []

for i in range(2,111):
    skill = sheet2.cell_value(i, 1)
    qualified_parents.append(skill)

print(qualified_parents)
# Out:
# ['Assembling', 'Casting', 'Fozzing', 'Technician', 'Machine Operator', 'Operator', 'Welder', 'Fitter', 'Electrician', 'Mechanic', 'Painter/polisher', 'Draughtman/autocad', 'Production', 'Maintenance', 'Worker/helper/majdoor', 'Supervisior', 'Quality Acessor/controller', 'Foreman', 'Moulder', 'Turner', 'Engineer', 'Carpenter', 'Tailor', 'Plumber', 'Dying operator', 'Accountant', 'Admin Executive', 'Advocate', 'Agriculture', 'Air Hostess', 'Architect', 'ATM Cash Filling Officer', 'Automobile', 'Beautician', 'Cabin Crew', 'Care Taker', 'CEO', 'Chef', 'Chemical Engineer', 'Construction', 'Computer Science Engineer', 'Conductor', 'Consultant', 'Content Writer', 'Counselor', 'Counter Sales', 'Credit Controller', 'Customer Care Executive', 'Data Analysis', 'Data Entry Operator', 'Designer', 'Developer', 'Driver', 'E Commerce Executive', 'Electrical Engineer', 'Equity Dealer', '', 'Fashion Designer', 'Field Boy', 'Freight', 'Handicraft', 'Jewellery', 'Lab Technician', 'Language Translator', 'Logistic Executive', 'Manufacturing', 'Marine Geologist', 'Marketing', 'Master Mason', 'Mechanical Engineer', 'Media Executive', 'Medical Assistant', 'Merchandiser', 'Mining Engineering', 'Networking', 'Nurse', 'Operations', 'Paravet', 'Peon', 'Personal Assistant', 'Pharmacist', 'Photographer', 'Printing', 'Process', 'Professor', 'Projectionist', 'Purchase Executive', 'Content Writer', 'Recovery Executive', 'Robotics Engineer', 'Sales', 'SAP Operator', 'Security Guard', 'Senior Research Analyst', 'Digital Marketing', 'Shoe Maker', 'Steward', 'Stock Incharge', 'System Administrator', 'Team leader', 'Technical Sales', 'Tender Executive', 'Test Engineer', 'Trade Finanace', 'Trainer', 'Transport Executive', 'Travel Agent', 'Warehouse Executive', 'Web Designer']

# %%
qualified_parents_dict = {}

for sk in qualified_parents:
    words = sk.split()
    
    for word in words:
        if(word in qualified_parents_dict):
            lst = qualified_parents_dict[word]
        else:
            lst = []
        lst.append(sk)
        qualified_parents_dict[word] = lst
        
print(qualified_parents_dict)
# Out:
# {'Assembling': ['Assembling'], 'Casting': ['Casting'], 'Fozzing': ['Fozzing'], 'Technician': ['Technician', 'Lab Technician'], 'Machine': ['Machine Operator'], 'Operator': ['Machine Operator', 'Operator', 'Data Entry Operator', 'SAP Operator'], 'Welder': ['Welder'], 'Fitter': ['Fitter'], 'Electrician': ['Electrician'], 'Mechanic': ['Mechanic'], 'Painter/polisher': ['Painter/polisher'], 'Draughtman/autocad': ['Draughtman/autocad'], 'Production': ['Production'], 'Maintenance': ['Maintenance'], 'Worker/helper/majdoor': ['Worker/helper/majdoor'], 'Supervisior': ['Supervisior'], 'Quality': ['Quality Acessor/controller'], 'Acessor/controller': ['Quality Acessor/controller'], 'Foreman': ['Foreman'], 'Moulder': ['Moulder'], 'Turner': ['Turner'], 'Engineer': ['Engineer', 'Chemical Engineer', 'Computer Science Engineer', 'Electrical Engineer', 'Mechanical Engineer', 'Robotics Engineer', 'Test Engineer'], 'Carpenter': ['Carpenter'], 'Tailor': ['Tailor'], 'Plumber': ['Plumber'], 'Dying': ['Dying operator'], 'operator': ['Dying operator'], 'Accountant': ['Accountant'], 'Admin': ['Admin Executive'], 'Executive': ['Admin Executive', 'Customer Care Executive', 'E Commerce Executive', 'Logistic Executive', 'Media Executive', 'Purchase Executive', 'Recovery Executive', 'Tender Executive', 'Transport Executive', 'Warehouse Executive'], 'Advocate': ['Advocate'], 'Agriculture': ['Agriculture'], 'Air': ['Air Hostess'], 'Hostess': ['Air Hostess'], 'Architect': ['Architect'], 'ATM': ['ATM Cash Filling Officer'], 'Cash': ['ATM Cash Filling Officer'], 'Filling': ['ATM Cash Filling Officer'], 'Officer': ['ATM Cash Filling Officer'], 'Automobile': ['Automobile'], 'Beautician': ['Beautician'], 'Cabin': ['Cabin Crew'], 'Crew': ['Cabin Crew'], 'Care': ['Care Taker', 'Customer Care Executive'], 'Taker': ['Care Taker'], 'CEO': ['CEO'], 'Chef': ['Chef'], 'Chemical': ['Chemical Engineer'], 'Construction': ['Construction'], 'Computer': ['Computer Science Engineer'], 'Science': ['Computer Science Engineer'], 'Conductor': ['Conductor'], 'Consultant': ['Consultant'], 'Content': ['Content Writer', 'Content Writer'], 'Writer': ['Content Writer', 'Content Writer'], 'Counselor': ['Counselor'], 'Counter': ['Counter Sales'], 'Sales': ['Counter Sales', 'Sales', 'Technical Sales'], 'Credit': ['Credit Controller'], 'Controller': ['Credit Controller'], 'Customer': ['Customer Care Executive'], 'Data': ['Data Analysis', 'Data Entry Operator'], 'Analysis': ['Data Analysis'], 'Entry': ['Data Entry Operator'], 'Designer': ['Designer', 'Fashion Designer', 'Web Designer'], 'Developer': ['Developer'], 'Driver': ['Driver'], 'E': ['E Commerce Executive'], 'Commerce': ['E Commerce Executive'], 'Electrical': ['Electrical Engineer'], 'Equity': ['Equity Dealer'], 'Dealer': ['Equity Dealer'], 'Fashion': ['Fashion Designer'], 'Field': ['Field Boy'], 'Boy': ['Field Boy'], 'Freight': ['Freight'], 'Handicraft': ['Handicraft'], 'Jewellery': ['Jewellery'], 'Lab': ['Lab Technician'], 'Language': ['Language Translator'], 'Translator': ['Language Translator'], 'Logistic': ['Logistic Executive'], 'Manufacturing': ['Manufacturing'], 'Marine': ['Marine Geologist'], 'Geologist': ['Marine Geologist'], 'Marketing': ['Marketing', 'Digital Marketing'], 'Master': ['Master Mason'], 'Mason': ['Master Mason'], 'Mechanical': ['Mechanical Engineer'], 'Media': ['Media Executive'], 'Medical': ['Medical Assistant'], 'Assistant': ['Medical Assistant', 'Personal Assistant'], 'Merchandiser': ['Merchandiser'], 'Mining': ['Mining Engineering'], 'Engineering': ['Mining Engineering'], 'Networking': ['Networking'], 'Nurse': ['Nurse'], 'Operations': ['Operations'], 'Paravet': ['Paravet'], 'Peon': ['Peon'], 'Personal': ['Personal Assistant'], 'Pharmacist': ['Pharmacist'], 'Photographer': ['Photographer'], 'Printing': ['Printing'], 'Process': ['Process'], 'Professor': ['Professor'], 'Projectionist': ['Projectionist'], 'Purchase': ['Purchase Executive'], 'Recovery': ['Recovery Executive'], 'Robotics': ['Robotics Engineer'], 'S ...

# %%
qualified_replacements = {}

for name in name_to_list_of_words_mapping:
    words = name_to_list_of_words_mapping[name]
    
    replacements = set()
    
    for word in words:
        if(word in qualified_parents_dict):
            replacements = replacements.union(set(qualified_parents_dict[word]))
    qualified_replacements[name] = replacements

# %%
print(len(qualified_replacements))
# Out:
# 15287

# %%
print(qualified_replacements['Project Lead Developer'])
# Out:
# {'Developer'}

# %%
import ssl 
from pymongo import MongoClient
client = MongoClient('127.0.0.1:27017')
db = client.the_incircle_dev_new
print(db.list_collection_names())
# Out:
# ['functionalareas', 'skills']

# %%
def find_skill_id(name):
    skill = db.skills.find_one({'name' : name})
    _id = None
    if(skill != None):
        _id = skill['_id']
    return _id
# Out:
# 5f7ef9237d5d3a013307fdca 5f7ef8d57d5d3a013307ddb4

# %%
def replaceParent(skill_id, new_parent_id):
    print(
            db.skills.update
            (
                {
                    '_id': skill_id
                }, 

                {
                  "$set": { 
                   'parent': ObjectId(new_parent_id)
                  }

                },
                upsert=True
            )
        )
    print('Parent Id After change : ', db.skills.find_one({'_id' : skill_id})['parent'])
# Out:
# {'n': 1, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9237d5d3a013307fdca
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   app.launch_new_instance()

# %%
import random

for qr in qualified_replacements:
    ln = len(qualified_replacements[qr])
    if(ln > 0):
        skill = qr
        parent = random.sample(list(qualified_replacements[qr]), 1)[0]
        
        skill_id = find_skill_id(skill)
        new_parent_id = find_skill_id(parent)
        replaceParent(skill_id, new_parent_id)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   app.launch_new_instance()
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9567d5d3a0133081327
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  60edd3a9b391d03d8a1860d7
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  60edd3a9b391d03d8a1860d8
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef8da7d5d3a013307dfa9
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef8f27d5d3a013307e948
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9577d5d3a0133081387
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef92b7d5d3a013308010c
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9577d5d3a0133081387
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7efa0a7d5d3a0133086304
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  60edd3a9b391d03d8a1860d9
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7efae17d5d3a013308c3e2
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef8f27d5d3a013307e948
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9517d5d3a01330810f9
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9037d5d3a013307f074
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9237d5d3a013307fdca
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7efae17d5d3a013308c3e2
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9577d5d3a0133081387
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7efae17d5d3a013308c3e2
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9bd7d5d3a013308407e
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9187d5d3a013307f91a
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9567d5d3a01330812e8
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef8fd7d5d3a013307edf8
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef93b7d5d3a01330807c0
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef9237d5d3a013307fdca
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef93a7d5d3a0133080736
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}
# Parent Id After change :  5f7ef