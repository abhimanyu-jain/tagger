# %%
# Reading an excel file using Python
import xlrd
from bson.objectid import ObjectId

# %%
# Give the location of the file
loc = ("functional_area & Parent Done.xls")

# %%
# To open Workbook
wb = xlrd.open_workbook(loc)
sheet = wb.sheet_by_index(1)

# %%
# For row 0 and column 0
print(sheet.cell_value(7, 11))
# Out:
# Cable Operator

# %%
parent_skills = {}
functional_roles = {}

# %%
for i in range(2, 117):
    for j in range(3, 17):
        val = sheet.cell_value(i, j)
        v = str(val)
        if not v: #getting rid of empty strings
            continue
        if(isinstance(val, str)):#only process strings
            #print(v)
            key = v
            value = sheet.cell_value(i, 1)
            functional_role = sheet.cell_value(i, 17)
            #print('key = ', key, 'value = ', value, 'functional role = ', functional_role)
            parent_skills[key] = value
            functional_roles[key] = functional_role

# %%
def print_dictionary(dic):
    for keys,values in dic.items():
        print('key : ', keys)
        print('value : ', values)

# %%
print_dictionary(parent_skills)
# Out:
# key :  Assembling
# value :  Assembling
# key :  Casting
# value :  Casting
# key :  Fozzing
# value :  Fozzing
# key :  Forging
# value :  Fozzing
# key :  Technician
# value :  Technician
# key :  CNC Machine Operator
# value :  Machine Operator
# key :  Machine Operator
# value :  Process
# key :  Crane Machine Operator
# value :  Machine Operator
# key :  Operator
# value :  Operator
# key :  CCTV Operator
# value :  Operator
# key :  DTH Installation
# value :  Operator
# key :  Cable Operator
# value :  Operator
# key :  Line Operator
# value :  Operator
# key :  Welder
# value :  Welder
# key :  Fitter
# value :  Fitter
# key :  Electrician
# value :  Electrician
# key :  Mechanic
# value :  Mechanic
# key :  Painter/polisher
# value :  Painter/polisher
# key :  POP Painter
# value :  Painter/polisher
# key :  Painter/Polisher
# value :  Painter/polisher
# key :  Draughtman/autocad
# value :  Draughtman/autocad
# key :  Production
# value :  Production
# key :  Senior Production Manager
# value :  Production
# key :  Maintenance
# value :  Maintenance
# key :  Maintenance Engineering
# value :  Maintenance
# key :  Worker/helper/majdoor
# value :  Worker/helper/majdoor
# key :  Factory Helper
# value :  Worker/helper/majdoor
# key :  Helper/labour
# value :  Worker/helper/majdoor
# key :  Helper
# value :  Worker/helper/majdoor
# key :  Labour
# value :  Worker/helper/majdoor
# key :  Supervisior
# value :  Supervisior
# key :  Supervisor
# value :  Supervisior
# key :  Quality Acessor/controller
# value :  Quality Acessor/controller
# key :  Senior Quality Engineer
# value :  Quality Acessor/controller
# key :  Foreman
# value :  Foreman
# key :  Moulder
# value :  Plastic Molding
# key :  Turner
# value :  Turner
# key :  Engineer
# value :  Engineer
# key :  ITI Engineer
# value :  Engineer
# key :  Carpenter
# value :  Carpenter
# key :  Tailor
# value :  Tailor
# key :  Garments
# value :  Tailor
# key :  Plumber
# value :  Plumber
# key :  Dying operator
# value :  Dying operator
# key :  Accountant
# value :  Accountant
# key :  Cashier
# value :  Accountant
# key :  Chartered Accountant
# value :  Accountant
# key :  Company Secretary
# value :  Accountant
# key :  Admin Executive
# value :  Admin Executive
# key :  HR Admin
# value :  Admin Executive
# key :  Advocate
# value :  Advocate
# key :  Legal
# value :  Advocate
# key :  Agriculture
# value :  Agriculture
# key :  Farmer
# value :  Agriculture
# key :  Air Hostess
# value :  Air Hostess
# key :  Aviation Airport
# value :  Air Hostess
# key :  Architect
# value :  Architect
# key :  ATM Cash Filling Officer
# value :  ATM Cash Filling Officer
# key :  Automobile
# value :  Automobile
# key :  Beautician
# value :  Beautician
# key :  Cabin Crew
# value :  Cabin Crew
# key :  Care Taker
# value :  Care Taker
# key :  CEO
# value :  CEO
# key :  Chef
# value :  Chef
# key :  Cook
# value :  Chef
# key :  Catering
# value :  Chef
# key :  House Maid
# value :  Chef
# key :  Chemical Engineer
# value :  Chemical Engineer
# key :  Civil Engineer
# value :  Construction
# key :  Construction
# value :  Construction
# key :  Computer Science Engineer
# value :  Computer Science Engineer
# key :  Conductor
# value :  Conductor
# key :  Toll Collector
# value :  Conductor
# key :  Consultant
# value :  Consultant
# key :  Content Writer
# value :  Content Writer
# key :  Counselor
# value :  Counselor
# key :  Counter Sales
# value :  Counter Sales
# key :  Retail Store Executive
# value :  Counter Sales
# key :  Credit Controller
# value :  Credit Controller
# key :  Customer Care Executive
# value :  Customer Care Executive
# key :  Telecaller
# value :  Customer Care Executive
# key :  Data Analysis
# value :  Data Analysis
# key :  Analysis
# value :  Data Analysis
# key :  Data Entry Operator
# value :  Data Entry Operator
# key :  Back Office Executive
# value :  Data Entry Operator
# key :  Designer
# value :  Designer
# key :  Developer
# value :  Developer
# key :  API Developer
# value :  Developer
# key :  Java Script JQuery
# value :  Developer
# key :  Driver
# value :  Driver
# key :  E Commerce Executive
# value :  E Commerce Executive
# key :  Electrical Engineer
# value :  Electrical Engineer
# key :  Electronic And Communication
# value :  Electrical Engineer
# key :  Electronics Instrumentation Engineer
# value :  Electrical Engineer
# key :  Equity Dealer
# value :  Equity Dealer
# key :  Event Executive
# value :  Event Executive
# key :  Fashion Designer
# value :  Fashion Designer
# key :  Field Boy
# value :  Field Boy
# key :  Delivery Boy
# value :  Field Boy
# key :  Freight
# value :  Freight
# key :  Handicraft
# value :  Handicraft
# key :  Jewellery
# value :  Jewellery
# key :  Lab Technician
# value :  Lab Technician
# key :  Language Translator
# value :  Language Translator
# key :  Loan Sales
# value :  Sales
# key :  Logistic Executive
# value :  Logistic Executive
# key :  Manufacturing
# value :  Manufacturing
# key :  Steel
# value :  Manufacturing
# key :  Marine Geologist
# value :  Marine Geologist
# key :  Marketing
# value :  Marketing
# key :  Master Mason
# value :  Master Mason
# key :  Mechanical Engineer
# value :  Mechanical Engineer
# key :  Media Executive
# value :  Media Executive
# key :  Medical Assistant
# value :  Medical Assistant
# key :  Doctor
# value :  Medical Assistant
# key :  Merchandiser
# value :  Merchandiser
# key :  Mining Engineering
# value :  Mining Engineering
# key :  Networking
# value :  Networking
# key :  Nurse
# value :  Nurse
# key :  Operations
# value :  Operations
# key :  Paravet
# value :  Paravet
# key :  Peon
# value :  Peon
# key :  Personal Assistant
# value :  Personal Assistant
# key :  Receptionist
# value :  Personal Assistant
# key :  Pharmacist
# value :  Pharmacist
# key :  Photographer
# value :  Photographer
# key :  Plastic Molding
# value :  Plastic Molding
# key :  Printing
# value :  Printing
# key :  Process
# value :  Process
# key :  Professor
# value :  Professor
# key :  Teacher
# value :  Professor
# key :  Projectionist
# value :  Projectionist
# key :  Purchase Executive
# value :  Purchase Executive
# key :  Supply Chain Executive
# value :  Purchase Executive
# key :  Quality Assurance Quality Control
# value :  Quality Assurance Quality Control
# key :  Quality Assurance/Quality Control
# value :  Quality Assurance Quality Control
# key :  Readiness Specialist
# value :  Content Writer
# key :  Recovery Executive
# value :  Recovery Executive
# key :  Robotics Engineer
# value :  Robotics Engineer
# key :  Sales
# value :  Sales
# key :  SAP Operator
# value :  SAP Operator
# key :  Security Guard
# value :  Security Guard
# key :  Senior Research Analyst
# value :  Senior Research Analyst
# key :  SEO Executive
# value :  Digital Marketing
# key :  Shoe Tailor Master
# value :  Shoe Maker
# key :  Steward
# value :  Steward
# key :  Stock Incharge
# value :  Stock Incharge
# key :  System Administrator
# value :  System Administrator
# key :  Team leader
# value :  Team leader
# key :  Technical Sales
# value :  Technical Sales
# key :  Tender Executive
# value :  Tender Executive
# key :  Test Engineer
# value :  Test Engineer
# key :  Trade Finanace
# value :  Trade Finanace
# key :  Trainer
# value :  Trainer
# key :  Gym Trainer
# value :  Trainer
# key :  Transport Executive
# value :  Transport Executive
# key :  Travel Agent
# value :  Travel Agent
# key :  Warehouse Executive
# value :  Warehouse Executive
# key :  Water Purifier
# value :  Technician
# key :  Web Designer
# value :  Web Designer
# key :  Graphic Designer
# value :  Web Designer

# %%
print_dictionary(functional_roles)
# Out:
# key :  Assembling
# value :  Fitter / Welder / Turner
# key :  Casting
# value :  Operator / Machinist / Moulder
# key :  Fozzing
# value :
# key :  Forging
# value :
# key :  Technician
# value :  Mechanic / Electrician / Technician
# key :  CNC Machine Operator
# value :  Operator / Machinist / Moulder
# key :  Machine Operator
# value :  Operator / Machinist / Moulder
# key :  Crane Machine Operator
# value :  Operator / Machinist / Moulder
# key :  Operator
# value :
# key :  CCTV Operator
# value :
# key :  DTH Installation
# value :
# key :  Cable Operator
# value :
# key :  Line Operator
# value :
# key :  Welder
# value :  Fitter / Welder / Turner
# key :  Fitter
# value :  Fitter / Welder / Turner
# key :  Electrician
# value :  Mechanic / Electrician / Technician
# key :  Mechanic
# value :  Mechanic / Electrician / Technician
# key :  Painter/polisher
# value :  Plumber / Painter / Carpenter
# key :  POP Painter
# value :  Plumber / Painter / Carpenter
# key :  Painter/Polisher
# value :  Plumber / Painter / Carpenter
# key :  Draughtman/autocad
# value :  Production / Maintenance
# key :  Production
# value :  Production / Maintenance
# key :  Senior Production Manager
# value :  Production / Maintenance
# key :  Maintenance
# value :  Production / Maintenance
# key :  Maintenance Engineering
# value :  Production / Maintenance
# key :  Worker/helper/majdoor
# value :  Labour / Helper / Worker
# key :  Factory Helper
# value :  Labour / Helper / Worker
# key :  Helper/labour
# value :  Labour / Helper / Worker
# key :  Helper
# value :  Labour / Helper / Worker
# key :  Labour
# value :  Labour / Helper / Worker
# key :  Supervisior
# value :  Production / Maintenance
# key :  Supervisor
# value :  Production / Maintenance
# key :  Quality Acessor/controller
# value :  Production / Maintenance
# key :  Senior Quality Engineer
# value :  Production / Maintenance
# key :  Foreman
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Moulder
# value :  Operator / Machinist / Moulder
# key :  Turner
# value :  Fitter / Welder / Turner
# key :  Engineer
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  ITI Engineer
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Carpenter
# value :  Plumber / Painter / Carpenter
# key :  Tailor
# value :  Tailor / Cutting Master
# key :  Garments
# value :  Tailor / Cutting Master
# key :  Plumber
# value :  Plumber / Painter / Carpenter
# key :  Dying operator
# value :  Operator / Machinist / Moulder
# key :  Accountant
# value :  Accounts / Finance
# key :  Cashier
# value :  Accounts / Finance
# key :  Chartered Accountant
# value :  Accounts / Finance
# key :  Company Secretary
# value :  Accounts / Finance
# key :  Admin Executive
# value :  HR / Recruiter / Admin
# key :  HR Admin
# value :  HR / Recruiter / Admin
# key :  Advocate
# value :  Advocate / Secretary / Stenography
# key :  Legal
# value :  Advocate / Secretary / Stenography
# key :  Agriculture
# value :  Labour / Helper / Worker
# key :  Farmer
# value :  Labour / Helper / Worker
# key :  Air Hostess
# value :  Ground Staff / Ticketing / Tour Agent
# key :  Aviation Airport
# value :  Ground Staff / Ticketing / Tour Agent
# key :  Architect
# value :  Architecture / Interior Design
# key :  ATM Cash Filling Officer
# value :  Security Guard / Watchman
# key :  Automobile
# value :  Production / Maintenance
# key :  Beautician
# value :  Beautician / Hair Stylist / Parlour
# key :  Cabin Crew
# value :  Ground Staff / Ticketing / Tour Agent
# key :  Care Taker
# value :  Maid / Aaya / Caretaker
# key :  CEO
# value :  Team Leader / Operation
# key :  Chef
# value :  Cook / Chef
# key :  Cook
# value :  Cook / Chef
# key :  Catering
# value :  Cook / Chef
# key :  House Maid
# value :  Cook / Chef
# key :  Chemical Engineer
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Civil Engineer
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Construction
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Computer Science Engineer
# value :  Software / Web Developer
# key :  Conductor
# value :  Labour / Helper / Worker
# key :  Toll Collector
# value :  Labour / Helper / Worker
# key :  Consultant
# value :  Counsellor
# key :  Content Writer
# value :  Content Writer
# key :  Counselor
# value :  Counsellor
# key :  Counter Sales
# value :  Retail / Counter Sales / Cashier
# key :  Retail Store Executive
# value :  Retail / Counter Sales / Cashier
# key :  Credit Controller
# value :  Accounts / Finance
# key :  Customer Care Executive
# value :  Team Leader / Operation
# key :  Telecaller
# value :  Team Leader / Operation
# key :  Data Analysis
# value :  Software / Web Developer
# key :  Analysis
# value :  Software / Web Developer
# key :  Data Entry Operator
# value :  Data Entry / Back Office
# key :  Back Office Executive
# value :  Data Entry / Back Office
# key :  Designer
# value :  Graphic / Web Design
# key :  Developer
# value :  Software / Web Developer
# key :  API Developer
# value :  Software / Web Developer
# key :  Java Script JQuery
# value :  Software / Web Developer
# key :  Driver
# value :  Driver / Pickup
# key :  E Commerce Executive
# value :  Digital Marketing / SEO
# key :  Electrical Engineer
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Electronic And Communication
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Electronics Instrumentation Engineer
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Equity Dealer
# value :  Loan / Insurance
# key :  Event Executive
# value :  Event Mgmt / Anchor / Journalist
# key :  Fashion Designer
# value :  Fashion Designer / Merchandiser
# key :  Field Boy
# value :  Delivery / Field
# key :  Delivery Boy
# value :  Delivery / Field
# key :  Freight
# value :  Warehouse / Logistics
# key :  Handicraft
# value :  Tailor / Cutting Master
# key :  Jewellery
# value :  Fashion Designer / Merchandiser
# key :  Lab Technician
# value :  Lab Technician / Pharmacist / Chemist
# key :  Language Translator
# value :  Content Writer
# key :  Loan Sales
# value :  Sales / Marketing
# key :  Logistic Executive
# value :  Warehouse / Logistics
# key :  Manufacturing
# value :  Operator / Machinist / Moulder
# key :  Steel
# value :  Operator / Machinist / Moulder
# key :  Marine Geologist
# value :  Teachers / Trainers
# key :  Marketing
# value :  Sales / Marketing
# key :  Master Mason
# value :  Labour / Helper / Worker
# key :  Mechanical Engineer
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Media Executive
# value :  Event Mgmt / Anchor / Journalist
# key :  Medical Assistant
# value :  Doctor / Dietitian
# key :  Doctor
# value :  Doctor / Dietitian
# key :  Merchandiser
# value :  Fashion Designer / Merchandiser
# key :  Mining Engineering
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Networking
# value :  Hardware / Networking
# key :  Nurse
# value :  Nurse / Compounder / Word Boy
# key :  Operations
# value :  Team Leader / Operation
# key :  Paravet
# value :
# key :  Peon
# value :  Housekeeping / Office Boy
# key :  Personal Assistant
# value :  Receptionist / Office Assistant
# key :  Receptionist
# value :  Receptionist / Office Assistant
# key :  Pharmacist
# value :  Lab Technician / Pharmacist / Chemist
# key :  Photographer
# value :  Event Mgmt / Anchor / Journalist
# key :  Plastic Molding
# value :  Operator / Machinist / Moulder
# key :  Printing
# value :  Operator / Machinist / Moulder
# key :  Process
# value :  Operator / Machinist / Moulder
# key :  Professor
# value :  Teachers / Trainers
# key :  Teacher
# value :  Teachers / Trainers
# key :  Projectionist
# value :  Event Mgmt / Anchor / Journalist
# key :  Purchase Executive
# value :  Warehouse / Logistics
# key :  Supply Chain Executive
# value :  Warehouse / Logistics
# key :  Quality Assurance Quality Control
# value :  Production / Maintenance
# key :  Quality Assurance/Quality Control
# value :  Production / Maintenance
# key :  Readiness Specialist
# value :  Content Writer
# key :  Recovery Executive
# value :  Delivery / Field
# key :  Robotics Engineer
# value :  Engineer(Mechanical ,Civil, Electrical etc.)
# key :  Sales
# value :  Sales / Marketing
# key :  SAP Operator
# value :  Data Entry / Back Office
# key :  Security Guard
# value :  Security Guard / Watchman
# key :  Senior Research Analyst
# value :  Lab Technician / Pharmacist / Chemist
# key :  SEO Executive
# value :  Digital Marketing / SEO
# key :  Shoe Tailor Master
# value :  Tailor / Cutting Master
# key :  Steward
# value :  Waiter / Steward
# key :  Stock Incharge
# value :  Loan / Insurance
# key :  System Administrator
# value :  Hardware / Networking
# key :  Team leader
# value :  Team Leader / Operation
# key :  Technical Sales
# value :  Telecaller/ Customer Service
# key :  Tender Executive
# value :  Data Entry / Back Office
# key :  Test Engineer
# value :  Software / Web Developer
# key :  Trade Finanace
# value :  Accounts / Finance
# key :  Trainer
# value :  Gym Trainers/ Yoga
# key :  Gym Trainer
# value :  Gym Trainers/ Yoga
# key :  Transport Executive
# value :  Warehouse / Logistics
# key :  Travel Agent
# value :  Ground Staff / Ticketing / Tour Agent
# key :  Warehouse Executive
# value :  Warehouse / Logistics
# key :  Water Purifier
# value :  Mechanic / Electrician / Technician
# key :  Web Designer
# value :  Graphic / Web Design
# key :  Graphic Designer
# value :  Graphic / Web Design

# %%
import ssl 
from pymongo import MongoClient
client = MongoClient('localhost:27017')
## Specify the database to be used
db = client.the_incircle_dev_new_may_27_2021
print(db)
skills = db.skills
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'the_incircle_dev_new_may_27_2021')

# %%
functionalareas = db.functionalareas

# %%
# Function which given a skill name, returns it's entire entry

def getSkillId(skill_name):
    skill = skills.find_one({'name' : skill_name})
    return skill

skill = getSkillId('Accountant')
print(skill)
# Out:
# {'_id': ObjectId('5f7ef8d57d5d3a013307ddb4'), 'collarType': 1, 'status': 1, 'name': 'Accountant', 'alias': 'accountant-jobs', 'functionalArea': ObjectId('5f7ef8bae4860d7fe2fc47ec'), 'updatedAt': datetime.datetime(2020, 10, 8, 11, 32, 37, 93000), 'createdAt': datetime.datetime(2020, 10, 8, 11, 32, 37, 93000), '__v': 0}

# %%
# Function which given a functionalarea name, returns it's entire entry

def getFunctionalAreaId(fa_name):
    fa = functionalareas.find_one({'name' : fa_name})
    return fa

fa = getFunctionalAreaId('Sales / Marketing')
print(fa)
# Out:
# {'_id': ObjectId('5f7ef8b9e4860d7fe2fc4660'), 'status': 1, 'name': 'Sales / Marketing', 'alias': 'sales-marketing', 'updatedAt': datetime.datetime(2021, 1, 21, 10, 40, 44, 721000), 'createdAt': datetime.datetime(2020, 10, 8, 11, 32, 9, 185000), '__v': 0, 'sort': 99.0}

# %%
# Iterate over parent_skills dictionary
    # For each key, find the record
    # Find id of value
    # set parent of key to value id

# %%
# Iterate over parent_skills functional_roles
    # For each key, find the record
    # Find id of value
    # set functionalArea of key to value id

# %%
# Function that accepts a skill and it's parent names, and sets the new parent

def setParent(skill, parent):
    skill_id = getSkillId(skill)
    parent_id  = getSkillId(parent)
    if parent_id == None:
        print('Parent ' , parent, ' does not exist!')
        return
    if skill_id == None:
        print('Skill ' , skill, ' does not exist!')
        return
    #print(skill_id['_id'])
    #print(parent_id['_id'])
    db.skills.update({'_id' : skill_id['_id']} ,{'$set': {'parent': ObjectId(parent_id['_id'])}})
    
#setParent('Tally', 'Accountant')

# %%
# Function that accepts a skill and sets it's functional area

def setFa(skill, fa):
    skill_id = getSkillId(skill)
    fa_id = getFunctionalAreaId(fa)
    if fa_id == None:
        print('Functional area ' , fa, ' does not exist!')
        return
    if skill_id == None:
        print('Skill ' , skill, ' does not exist!')
        return
    #print(skill_id['_id'])
    #print(fa_id['_id'])
    db.skills.update({'_id' : skill_id['_id']}
                    ,{'$set': {
                        'functionalArea': ObjectId(fa_id['_id'])
                    }})
    
#setParent('Tally', 'Accounts / Finance')

# %%
# Iterate over skill

for key in parent_skills:
    parent = parent_skills[key]
    setParent(key, parent)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# Parent  Process  does not exist!
# Parent  Painter/polisher  does not exist!
# Parent  Painter/polisher  does not exist!
# Parent  Painter/polisher  does not exist!
# Parent  Draughtman/autocad  does not exist!
# Skill  Maintenance Engineering  does not exist!
# Parent  Worker/helper/majdoor  does not exist!
# Parent  Worker/helper/majdoor  does not exist!
# Parent  Worker/helper/majdoor  does not exist!
# Parent  Worker/helper/majdoor  does not exist!
# Parent  Worker/helper/majdoor  does not exist!
# Parent  Quality Acessor/controller  does not exist!
# Parent  Quality Acessor/controller  does not exist!
# Skill  ITI Engineer  does not exist!
# Parent  Dying operator  does not exist!
# Skill  Aviation Airport  does not exist!
# Parent  CEO  does not exist!
# Parent  Content Writer  does not exist!
# Skill  Doctor  does not exist!
# Parent  Process  does not exist!
# Skill  Quality Assurance/Quality Control  does not exist!
# Parent  Content Writer  does not exist!
# Parent  Test Engineer  does not exist!
# Parent  Trainer  does not exist!
# Parent  Trainer  does not exist!
# Skill  Water Purifier  does not exist!

# %%
# Iterate over skill

for key in functional_roles:
    fa = functional_roles[key]
    setFa(key, fa)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   app.launch_new_instance()
# Functional area  Operator / Machinist / Moulder  does not exist!
# Functional area    does not exist!
# Functional area    does not exist!
# Functional area  Operator / Machinist / Moulder  does not exist!
# Functional area  Operator / Machinist / Moulder  does not exist!
# Functional area  Operator / Machinist / Moulder  does not exist!
# Functional area    does not exist!
# Functional area    does not exist!
# Functional area    does not exist!
# Functional area    does not exist!
# Functional area    does not exist!
# Skill  Painter/polisher  does not exist!
# Skill  Painter/Polisher  does not exist!
# Skill  Draughtman/autocad  does not exist!
# Skill  Maintenance Engineering  does not exist!
# Skill  Worker/helper/majdoor  does not exist!
# Skill  Helper/labour  does not exist!
# Skill  Quality Acessor/controller  does not exist!
# Functional area  Operator / Machinist / Moulder  does not exist!
# Skill  ITI Engineer  does not exist!
# Functional area  Operator / Machinist / Moulder  does not exist!
# Skill  Aviation Airport  does not exist!
# Skill  CEO  does not exist!
# Skill  Content Writer  does not exist!
# Functional area  Operator / Machinist / Moulder  does not exist!
# Functional area  Operator / Machinist / Moulder  does not exist!
# Skill  Doctor  does not exist!
# Functional area    does not exist!
# Functional area  Operator / Machinist / Moulder  does not exist!
# Functional area  Operator / Machinist / Moulder  does not exist!
# Functional area  Operator / Machinist / Moulder  does not exist!
# Skill  Quality Assurance/Quality Control  does not exist!
# Functional area  Telecaller/ Customer Service  does not exist!
# Skill  Test Engineer  does not exist!
# Functional area  Gym Trainers/ Yoga  does not exist!
# Functional area  Gym Trainers/ Yoga  does not exist!
# Skill  Water Purifier  does not exist!
